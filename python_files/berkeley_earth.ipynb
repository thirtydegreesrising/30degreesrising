# %% [markdown]
# ### **1. Load the required libraries**

# %%
import tarfile
import os

import pandas as pd
import xarray as xr
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### **2. Extract files from the tar files**

# %%
path = r'/content/drive/MyDrive/group_project/data'

# %%
#os.chdir(path)
#fname = os.listdir(".")[0]

#tar = tarfile.open(fname, "r:gz")
#tar.extractall()
#tar.close()

# %% [markdown]
# ### **3. Create the CSV Files**

# %%
for filename in os.listdir(path):
    f = os.path.join(path, filename)
    if os.path.splitext(f)[-1] == ".nc": # check if it's a .nc file
        tas_hist = xr.open_dataset(filename)
        df = tas_hist.to_dataframe()
        df.reset_index(inplace=True) # collapse by 1 level to flatten df
        df["time"] = df["time"].dt.strftime('%d-%m-%Y') # reformat the time column to leave only the date information
        df["time"]= pd.to_datetime(df["time"]) # change back into datetime format
        df["year"] = pd.DatetimeIndex(df["time"]).year # make a new column containing the year
        df = df.dropna() # clean up to drop N/A values
        df = df.groupby(["latitude", "longitude", "year"], as_index=False)["tas"].mean() # calculate avg temp anomaly over year for each set of latitude and longitude coordinates
        df.to_csv("/content/drive/MyDrive/group_project/outputs/anomaly_" + filename[-12:-8] + ".csv", index = False, header = False) # write the dataframe to a csv

# %% [markdown]
# ### **4. Generate Plots**

# %%
os.chdir(path)

# %% [markdown]
# #### **1980**

# %%
tas_hist_80 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_1980_v1.0.nc")

# %%
tas_hist_80_ann_mean = tas_hist_80["tas"].mean("time")

# %%
tas_hist_80_ann_mean.plot()

# %% [markdown]
# #### **1985**

# %%
tas_hist_85 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_1985_v1.0.nc")

# %%
tas_hist_85_ann_mean = tas_hist_85["tas"].mean("time")

# %%
tas_hist_85_ann_mean.plot()

# %% [markdown]
# #### **1990**

# %%
tas_hist_90 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_1990_v1.0.nc")

# %%
tas_hist_90_ann_mean = tas_hist_90["tas"].mean("time")

# %%
tas_hist_90_ann_mean.plot()

# %% [markdown]
# #### **1995**

# %%
tas_hist_95 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_1995_v1.0.nc")

# %%
tas_hist_95_ann_mean = tas_hist_95["tas"].mean("time")

# %%
tas_hist_95_ann_mean.plot()

# %% [markdown]
# #### **2000**

# %%
tas_hist_00 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_2000_v1.0.nc")

# %%
tas_hist_00_ann_mean = tas_hist_00["tas"].mean("time")

# %%
tas_hist_00_ann_mean.plot()

# %% [markdown]
# #### **2005**

# %%
tas_hist_05 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_2005_v1.0.nc")

# %%
tas_hist_05_ann_mean = tas_hist_05["tas"].mean("time")

# %%
tas_hist_05_ann_mean.plot()

# %% [markdown]
# #### **2010**

# %%
tas_hist_10 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_2010_v1.0.nc")

# %%
tas_hist_10_ann_mean = tas_hist_10["tas"].mean("time")

# %%
tas_hist_10_ann_mean.plot()

# %% [markdown]
# #### **2015**

# %%
tas_hist_15 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_2015_v1.0.nc")

# %%
tas_hist_15_ann_mean = tas_hist_15["tas"].mean("time")

# %%
tas_hist_15_ann_mean.plot()

# %% [markdown]
# #### **2019**

# %%
tas_hist_19 = xr.open_dataset("BERKEARTH_mean_temperature-anomaly_mon_1x1_global_2019_v1.0.nc")

# %%
tas_hist_19_ann_mean = tas_hist_19["tas"].mean("time")

# %%
tas_hist_19_ann_mean.plot()
