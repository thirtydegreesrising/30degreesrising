# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('41586_2021_3436_MOESM5_ESM.xlsx',skiprows=[1])

# %%
df
# Out:
#       Latitude of southern tile corner  Longitude of western tile corner  \
# 0                                    0                                29
# 1                                    0                               -78
# 2                                    0                               -79
# 3                                    2                               -77
# 4                                    4                               -76
# ...                                ...                               ...
# 1437                               -80                               166
# 1438                               -80                               168
# 1439                               -80                              -150
# 1440                               -80                              -152
# 1441                               -80                              -156
#
#       Tile size in latitude  Tile size in longitude  \
# ...

# %%
df2=df[df['Latitude of southern tile corner']>60]

# %%
df2.to_csv('Mean_ECR_tiles.csv')
